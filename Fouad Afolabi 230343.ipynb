# %%
import numpy as np
import pandas as pd

# %%
rr= pd.read_csv('Real_Estate_Sales_2001-2020_GL.csv')
rr
# Out:
# /var/folders/c8/jxx1plc12tgdhzjqvzbjl_mw0000gn/T/ipykernel_12023/4143501298.py:1: DtypeWarning: Columns (8,9,10,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   rr= pd.read_csv('Real_Estate_Sales_2001-2020_GL.csv')
#         Serial Number  List Year Date Recorded           Town  \
# 0             2020348       2020    09/13/2021        Ansonia
# 1               20002       2020    10/02/2020        Ashford
# 2              200212       2020    03/09/2021           Avon
# 3              200243       2020    04/13/2021           Avon
# 4              200377       2020    07/02/2021           Avon
# ...               ...        ...           ...            ...
# 997208         190272       2019    06/24/2020     New London
# 997209         190284       2019    11/27/2019      Waterbury
# 997210         190129       2019    04/27/2020  Windsor Locks
# 997211         190504       2019    06/03/2020     Middletown
# ...

# %%
rr.drop_duplicates()
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 0             2020348       2020    09/13/2021        Ansonia
# 1               20002       2020    10/02/2020        Ashford
# 2              200212       2020    03/09/2021           Avon
# 3              200243       2020    04/13/2021           Avon
# 4              200377       2020    07/02/2021           Avon
# ...               ...        ...           ...            ...
# 997208         190272       2019    06/24/2020     New London
# 997209         190284       2019    11/27/2019      Waterbury
# 997210         190129       2019    04/27/2020  Windsor Locks
# 997211         190504       2019    06/03/2020     Middletown
# 997212         190344       2019    12/20/2019        Milford
#
#                       Address  Assessed Value  Sale Amount  Sales Ratio  \
# 0             230 WAKELEE AVE        150500.0     325000.0     0.463000
# 1             390 TURNPIKE RD        253000.0     430000.0     0.588300
# ...

# %%
rr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 997213 entries, 0 to 997212
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Serial Number     997213 non-null  int64
#  1   List Year         997213 non-null  int64
#  2   Date Recorded     997211 non-null  object
#  3   Town              997213 non-null  object
#  4   Address           997162 non-null  object
#  5   Assessed Value    997213 non-null  float64
#  6   Sale Amount       997213 non-null  float64
#  7   Sales Ratio       997213 non-null  float64
#  8   Property Type     614767 non-null  object
#  9   Residential Type  608904 non-null  object
#  10  Non Use Code      289681 non-null  object
#  11  Assessor Remarks  149864 non-null  object
#  12  OPM remarks       9934 non-null    object
#  13  Location          197697 non-null  object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 106.5+ MB

# %%
rr.describe()
# Out:
#        Serial Number      List Year  Assessed Value   Sale Amount  \
# count   9.972130e+05  997213.000000    9.972130e+05  9.972130e+05
# mean    4.311864e+05    2010.189829    2.791437e+05  3.911512e+05
# std     6.549219e+06       6.237877    1.670610e+06  5.347270e+06
# min     0.000000e+00    2001.000000    0.000000e+00  0.000000e+00
# 25%     3.044400e+04    2004.000000    8.760000e+04  1.400000e+05
# 50%     7.030300e+04    2010.000000    1.383900e+05  2.250000e+05
# 75%     1.518780e+05    2016.000000    2.255600e+05  3.650000e+05
# max     2.000500e+09    2020.000000    8.815100e+08  5.000000e+09
#
#         Sales Ratio
# count  9.972130e+05
# mean   1.044637e+01
# std    1.890192e+03
# min    0.000000e+00
# 25%    4.867000e-01
# 50%    6.246000e-01
# 75%    7.852761e-01
# max    1.226420e+06

# %%
rr[rr['Town'] == '***Unknown***']
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 444657          70086       2007    12/18/2007  ***Unknown***
#
#                 Address  Assessed Value  Sale Amount  Sales Ratio  \
# 444657  18 MATHIEU LANE         66540.0     282450.0     0.235582
#
#         Property Type Residential Type             Non Use Code  \
# 444657  Single Family    Single Family  07 - Change in Property
#
#        Assessor Remarks OPM remarks Location
# 444657              NaN         NaN      NaN

# %%
rr.drop(index=444657, axis=0)
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 0             2020348       2020    09/13/2021        Ansonia
# 1               20002       2020    10/02/2020        Ashford
# 2              200212       2020    03/09/2021           Avon
# 3              200243       2020    04/13/2021           Avon
# 4              200377       2020    07/02/2021           Avon
# ...               ...        ...           ...            ...
# 997208         190272       2019    06/24/2020     New London
# 997209         190284       2019    11/27/2019      Waterbury
# 997210         190129       2019    04/27/2020  Windsor Locks
# 997211         190504       2019    06/03/2020     Middletown
# 997212         190344       2019    12/20/2019        Milford
#
#                       Address  Assessed Value  Sale Amount  Sales Ratio  \
# 0             230 WAKELEE AVE        150500.0     325000.0     0.463000
# 1             390 TURNPIKE RD        253000.0     430000.0     0.588300
# ...

# %%
rr.drop(['Non Use Code','Assessor Remarks','OPM remarks','Location'],axis=1, inplace=True)

# %%
rr
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 0             2020348       2020    09/13/2021        Ansonia
# 1               20002       2020    10/02/2020        Ashford
# 2              200212       2020    03/09/2021           Avon
# 3              200243       2020    04/13/2021           Avon
# 4              200377       2020    07/02/2021           Avon
# ...               ...        ...           ...            ...
# 997208         190272       2019    06/24/2020     New London
# 997209         190284       2019    11/27/2019      Waterbury
# 997210         190129       2019    04/27/2020  Windsor Locks
# 997211         190504       2019    06/03/2020     Middletown
# 997212         190344       2019    12/20/2019        Milford
#
#                       Address  Assessed Value  Sale Amount  Sales Ratio  \
# 0             230 WAKELEE AVE        150500.0     325000.0     0.463000
# 1             390 TURNPIKE RD        253000.0     430000.0     0.588300
# ...

# %%
rr.dropna(axis=0, inplace=True)

# %%
rr
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 1               20002       2020    10/02/2020        Ashford
# 2              200212       2020    03/09/2021           Avon
# 3              200243       2020    04/13/2021           Avon
# 4              200377       2020    07/02/2021           Avon
# 5              200109       2020    12/09/2020           Avon
# ...               ...        ...           ...            ...
# 997207         190272       2019    08/03/2020         Wilton
# 997208         190272       2019    06/24/2020     New London
# 997209         190284       2019    11/27/2019      Waterbury
# 997210         190129       2019    04/27/2020  Windsor Locks
# 997211         190504       2019    06/03/2020     Middletown
#
#                       Address  Assessed Value  Sale Amount  Sales Ratio  \
# 1             390 TURNPIKE RD        253000.0     430000.0     0.588300
# 2            5 CHESTNUT DRIVE        130400.0     179900.0     0.724800
# ...

# %%
rr.reset_index(drop=True)
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 0               20002       2020    10/02/2020        Ashford
# 1              200212       2020    03/09/2021           Avon
# 2              200243       2020    04/13/2021           Avon
# 3              200377       2020    07/02/2021           Avon
# 4              200109       2020    12/09/2020           Avon
# ...               ...        ...           ...            ...
# 608895         190272       2019    08/03/2020         Wilton
# 608896         190272       2019    06/24/2020     New London
# 608897         190284       2019    11/27/2019      Waterbury
# 608898         190129       2019    04/27/2020  Windsor Locks
# 608899         190504       2019    06/03/2020     Middletown
#
#                       Address  Assessed Value  Sale Amount  Sales Ratio  \
# 0             390 TURNPIKE RD        253000.0     430000.0     0.588300
# 1            5 CHESTNUT DRIVE        130400.0     179900.0     0.724800
# ...

# %% [markdown]
# * Finding the total sales by Residential Type

# %%
rr['Residential Type'].unique()
# Out:
# array(['Single Family', 'Condo', 'Two Family', 'Three Family',
#        'Four Family'], dtype=object)

# %%
rr.groupby('Residential Type')['Sale Amount'].sum().sort_values(ascending=False)
# Out:
# Residential Type
# Single Family    1.783574e+11
# Condo            3.265330e+10
# Two Family       6.127529e+09
# Three Family     2.868236e+09
# Four Family      7.615052e+08
# Name: Sale Amount, dtype: float64

# %% [markdown]
# * Generate a new table that sort your data using column Sales Ratio from the highest to the minimum

# %%
dd=rr.sort_values('Sales Ratio', ascending=False)

# %%
dd
# Out:
#         Serial Number  List Year Date Recorded          Town  \
# 421304          60043       2006    03/19/2007     Salisbury
# 424013          60190       2006    03/02/2007       Newtown
# 425795          60213       2006    03/29/2007       Newtown
# 893093         180020       2018    10/29/2018  Beacon Falls
# 422591          60442       2006    09/14/2007      Guilford
# ...               ...        ...           ...           ...
# 15897          200128       2020    10/26/2020       Danbury
# 707230         140064       2014    05/21/2015  Beacon Falls
# 631071         120108       2012    05/24/2013      Griswold
# 395268          60106       2006    03/01/2007  East Windsor
# 920925         180185       2018    06/21/2019     Ellington
#
#                                Address  Assessed Value  Sale Amount  \
# 421304                     209 MAIN ST       1226420.0          1.0
# 424013                 17 WHITEWOOD RD        473780.0          1.0
# ...

# %% [markdown]
# * Find the first 10 Sales with the highest amount in a dataframe

# %%
rr.sort_values('Sale Amount', ascending=False).head(10)
# Out:
#         Serial Number  List Year Date Recorded        Town  \
# 60894        20200078       2020    07/06/2021  Willington
# 65620        20200102       2020    09/28/2021  Willington
# 957543         191094       2019    08/12/2020     Norwalk
# 655816         130446       2013    04/11/2014   Greenwich
# 47039         2000802       2020    01/15/2021    Stamford
# 34836         2000813       2020    01/15/2021    Stamford
# 45129         2000796       2020    01/15/2021    Stamford
# 30399         2000810       2020    01/15/2021    Stamford
# 44648         2000818       2020    01/15/2021    Stamford
# 39028         2000812       2020    01/15/2021    Stamford
#
#                         Address  Assessed Value  Sale Amount  Sales Ratio  \
# 60894            224 RIVER ROAD        223070.0  318790019.0     0.000700
# 65620   7 TOLLAND TURNPIKE ROAD        112040.0  194149073.0     0.000577
# 957543            33 ORCHARD ST        507580.0  157000000.0     0.003200
# ...

# %% [markdown]
# * Return the min, the max and the total sales of Estate

# %%
rr['Sale Amount'].min()
# Out:
# 0.0

# %%
rr['Sale Amount'].max()
# Out:
# 318790019.0

# %%
rr['Sale Amount'].sum()
# Out:
# 220767975970.26

# %% [markdown]
# * Congratulations on your new job as a data analyst in a Real Estate company, we realize that as years goes by, we are begining to experience..changes in our sales, can you draw a conclusion for your new employer, the effect of time on the company sales?

# %%
rr.groupby('List Year')['Sale Amount'].sum().sort_values(ascending=False)
# Out:
# List Year
# 2020    2.911034e+10
# 2019    2.043337e+10
# 2006    1.851432e+10
# 2016    1.789911e+10
# 2014    1.565758e+10
# 2018    1.471580e+10
# 2017    1.448117e+10
# 2009    1.323151e+10
# 2007    1.236078e+10
# 2015    1.217800e+10
# 2013    1.211541e+10
# 2012    1.183023e+10
# 2011    1.015721e+10
# 2008    9.051819e+09
# 2010    9.031316e+09
# Name: Sale Amount, dtype: float64

# %%
# rr['profit']= rr['Sale Amount']- rr['Assessed Value']
x = rr[rr['profit'] < 0]
x
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 2552           200209       2020    05/03/2021     Colchester
# 5894           200525       2020    01/25/2021        Danbury
# 9853           200901       2020    05/04/2021        Danbury
# 13928           20524       2020    05/07/2021  East Hartford
# 42703          200672       2020    12/29/2020        Norwalk
# ...               ...        ...           ...            ...
# 976975          19023       2019    10/18/2019      Montville
# 980125         190340       2019    06/18/2020       Trumbull
# 988393         190349       2019    08/17/2020     New London
# 988666         190101       2019    06/17/2020      Westbrook
# 993143         190342       2019    01/06/2020        Norwalk
#
#                  Address  Assessed Value  Sale Amount  Sales Ratio  \
# 2552       28 PHOENIX RD         19300.0      10000.0     1.930000
# 5894    19 RIDGECREST RD        326400.0     173000.0     1.886705
# ...

# %%
rr.drop(x)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 rr.drop(x)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %% [markdown]
# * Kindly advise the company, which town should they stop selling Estate,advise the company, which town should we continue selling our Real Estate

# %%
rr.groupby('Town')['Sale Amount'].sum().sort_values(ascending=False)
# Out:
# Town
# Greenwich        2.547737e+10
# Stamford         1.091565e+10
# Westport         8.312977e+09
# Fairfield        7.743334e+09
# Norwalk          7.413831e+09
#                      ...
# Eastford         5.807672e+07
# Franklin         5.683643e+07
# Scotland         5.258923e+07
# Union            3.109705e+07
# ***Unknown***    2.824500e+05
# Name: Sale Amount, Length: 170, dtype: float64

# %% [markdown]
# * The company should stop selling at Eastford,Franklin,Scotland and Union because of low sales of properties in those Towns
# * The company should continue selling at Greenwich,Stamford,Westport,Fairfield and Norwalk because of the high sales of properties in those Towns

# %% [markdown]
# We have different properties in our company, which property will you advise us to stop selling and which will you advise us to sell more of it

# %%
rr.groupby('Property Type')['Sale Amount'].mean().sort_values(ascending=False)
# Out:
# Property Type
# Residential      479356.211359
# Single Family    388514.465503
# Four Family      314291.035814
# Condo            260208.716451
# Two Family       199043.662241
# Three Family     179844.516208
# Name: Sale Amount, dtype: float64

# %% [markdown]
# According to the result, it will be advised the company should stop the sale of Two Family and Three Family while the company should sell more of Residential properties
